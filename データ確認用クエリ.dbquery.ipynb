-- %%
-- Bronzeテーブル確認用
select * from `handson`.`sports_orders`.`bronze_sports_orders`;

-- Silverテーブル確認用
select * from `handson`.`sports_orders`.`silver_sports_orders`;

-- Goldテーブル確認用
select * from `handson`.`sports_orders`.`gold_sports_summary`;
