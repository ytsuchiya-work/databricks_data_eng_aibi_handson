# %%
import pandas as pd
import numpy as np

order_ids = np.arange(1, 103)
shipment_status = np.random.choice(['発送済み', '準備中'], size=102)
df = pd.DataFrame({'order_id': order_ids, 'shipment_status': shipment_status})

df.to_csv('Data/shipment.csv', index=False)
